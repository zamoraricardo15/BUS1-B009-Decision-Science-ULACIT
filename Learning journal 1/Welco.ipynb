# %% [markdown]
# <a href="https://colab.research.google.com/github/zamoraricardo15/BUS1-B009_Decision-Science_ULACIT/blob/main/Learning%20journal%201/Welco.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = "Hello World!"
print(x)
# Out:
# Hello World!
